# %% [markdown]
# # Variation 1 : external insulation
#
# For this first variation, we chose to replace the internal insulation by an external insulation. We obtain the following results.

# %%
run variant1.ipynb
# Out:
# σ = 5.67e-08 W/(m²⋅K⁴)
# For 0°C < (T/K - 273.15)°C < 40°C, 4σT³/[W/(m²·K)] ∈ [4.6 7. ]
# For 10°C < (T/K - 273.15)°C < 30°C, 4σT³/[W/(m²·K)] ∈ [5.1 6.3]
# For (T/K - 273.15)°C = 20°C, 4σT³ = 5.7 W/(m²·K)
# θss = [10. 10. 10. 10. 10. 10. 10. 10.] °C
# uss = [10 10 10 20  0  0  0  0]
# yss = 10.00 °C
# Error between DAE and state-space: 7.11e-15 °C
# Time constants:
# ['105.78 s', '4077.28 s', '4427.08 s', '248789.58 s']
#
# 2 x Time constants:
# ['211.56 s', '8154.56 s', '8854.17 s', '497579.16 s']
#
# Maximum time step: 211.56 s = 3.53 min
# dt = 180.0 s = 3 min
# 4 * Time constants:
#  [   420  16308  17708 995156] s
#
# Settling time: 995158 s = 16586.0 min = 276.43 h = 11.52 days
# Matrices and vectors for thermal circuit from Figure 1
# θss = [10. 10. 10. 10. 10. 10. 10. 10.] °C
# θssQ = [ 0.14  5.38 10.62 10.87 11.12  5.57 12.26  4.41] °C
# uss = [10 10 10 20  0  0  0  0]
# yss = 10.00 °C
# Error between DAE and state-space: 7.11e-15 °C
# yssQ = 12.26 °C
# ...

# %% [markdown]
# the first graph represents the evolution of indoor temperature without internal loads
# the second graph represents the evolution of indoor temperature with internal loads

# %% [markdown]
# We can observe that compared to the initial model, the settling time is much longer : the steady-state with the internal insulation is reached after 2,04 days, whereas it is reached after 11,52 days with the external insulation.

# %% [markdown]
# The duration is also longer : 49h compared to 277h.
