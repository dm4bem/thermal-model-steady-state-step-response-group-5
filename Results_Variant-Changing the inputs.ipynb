# %% [markdown]
# # Variant: Changing the inputs
#
# The start- and end-date were changed to study potential result variances.

# %%
run INPUT.py
# Out:
# σ = 5.67e-08 W/(m²⋅K⁴)
# For 0°C < (T/K - 273.15)°C < 40°C, 4σT³/[W/(m²·K)] ∈ [4.6 7. ]
# For 10°C < (T/K - 273.15)°C < 30°C, 4σT³/[W/(m²·K)] ∈ [5.1 6.3]
# For (T/K - 273.15)°C = 20°C, 4σT³ = 5.7 W/(m²·K)
# θss = [10.11 10.32 10.52 14.76 19.   14.5  19.92 13.57] °C
# uss = [10 10 10 20  0  0  0  0]
# yss = 19.92 °C
# Error between DAE and state-space: 3.55e-15 °C
# Time constants:
# ['3.20 s', '4084.51 s', '4282.10 s', '43729.25 s']
#
# 2 x Time constants:
# ['6.40 s', '8169.02 s', '8564.20 s', '87458.51 s']
#
# Maximum time step: 6.40 s = 0.11 min
# dt = 6.0 s
# 4 * Time constants:
#  [    12  16336  17128 174916] s
#
# Settling time: 174917 s = 2915.3 min = 48.59 h = 2.02 days
# Matrices and vectors for thermal circuit from Figure 1
# θss = [10. 10. 10. 10. 10. 10. 10. 10.] °C
# θssQ = [ 0.14  0.39  0.65  5.88 11.12  5.57 12.26  4.41] °C
# uss = [10 10 10 20  0  0  0  0]
# yss = 10.00 °C
# Error between DAE and state-space: 5.33e-15 °C
# yssQ = 12.26 °C
# ...

# %% [markdown]
# The original dates were in february and were changed to the summertime, more precisely the month of july.

# %%
run INPUT_summertime.py
# Out:
# σ = 5.67e-08 W/(m²⋅K⁴)
# For 0°C < (T/K - 273.15)°C < 40°C, 4σT³/[W/(m²·K)] ∈ [4.6 7. ]
# For 10°C < (T/K - 273.15)°C < 30°C, 4σT³/[W/(m²·K)] ∈ [5.1 6.3]
# For (T/K - 273.15)°C = 20°C, 4σT³ = 5.7 W/(m²·K)
# θss = [10.11 10.32 10.52 14.76 19.   14.5  19.92 13.57] °C
# uss = [10 10 10 20  0  0  0  0]
# yss = 19.92 °C
# Error between DAE and state-space: 3.55e-15 °C
# Time constants:
# ['3.20 s', '4084.51 s', '4282.10 s', '43729.25 s']
#
# 2 x Time constants:
# ['6.40 s', '8169.02 s', '8564.20 s', '87458.51 s']
#
# Maximum time step: 6.40 s = 0.11 min
# dt = 6.0 s
# 4 * Time constants:
#  [    12  16336  17128 174916] s
#
# Settling time: 174917 s = 2915.3 min = 48.59 h = 2.02 days
# Matrices and vectors for thermal circuit from Figure 1
# θss = [10. 10. 10. 10. 10. 10. 10. 10.] °C
# θssQ = [ 0.14  0.39  0.65  5.88 11.12  5.57 12.26  4.41] °C
# uss = [10 10 10 20  0  0  0  0]
# yss = 10.00 °C
# Error between DAE and state-space: 5.33e-15 °C
# yssQ = 12.26 °C
# ...

# %% [markdown]
# Despite these modifications and also the prolongation of the simulation time no changes could be seen.

# %%
run INPUT_summertime_longer.py
# Out:
# σ = 5.67e-08 W/(m²⋅K⁴)
# For 0°C < (T/K - 273.15)°C < 40°C, 4σT³/[W/(m²·K)] ∈ [4.6 7. ]
# For 10°C < (T/K - 273.15)°C < 30°C, 4σT³/[W/(m²·K)] ∈ [5.1 6.3]
# For (T/K - 273.15)°C = 20°C, 4σT³ = 5.7 W/(m²·K)
# θss = [10.11 10.32 10.52 14.76 19.   14.5  19.92 13.57] °C
# uss = [10 10 10 20  0  0  0  0]
# yss = 19.92 °C
# Error between DAE and state-space: 3.55e-15 °C
# Time constants:
# ['3.20 s', '4084.51 s', '4282.10 s', '43729.25 s']
#
# 2 x Time constants:
# ['6.40 s', '8169.02 s', '8564.20 s', '87458.51 s']
#
# Maximum time step: 6.40 s = 0.11 min
# dt = 6.0 s
# 4 * Time constants:
#  [    12  16336  17128 174916] s
#
# Settling time: 174917 s = 2915.3 min = 48.59 h = 2.02 days
# Matrices and vectors for thermal circuit from Figure 1
# θss = [10. 10. 10. 10. 10. 10. 10. 10.] °C
# θssQ = [ 0.14  0.39  0.65  5.88 11.12  5.57 12.26  4.41] °C
# uss = [10 10 10 20  0  0  0  0]
# yss = 10.00 °C
# Error between DAE and state-space: 5.33e-15 °C
# yssQ = 12.26 °C
# ...
